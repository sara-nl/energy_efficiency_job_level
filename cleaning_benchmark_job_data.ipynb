# %%
import pandas as pd
import numpy as np
from pathlib import Path

from utils import extract_job_data, get_slurm_data, format_node_names

# %%
def preprocess_slurm(df: object) -> object:
    """processing the slurm data

    Args:
        df (object): a data frame with job id and the feature

    Returns:
        object: a dataframe with extracted features as its columns
    """

    df['feature'] = df['feature'].str.split('\n')
    df['length_of_feature'] = [len(l) for l in df['feature'].tolist()]
    # df['length_of_feature'].value_counts()[0:10]
    
    
    
 
    lower_bound = 0
    upper_bound = len(df)
    data_processed = []

    for n in range(lower_bound, upper_bound):

        len_feature = df.iloc[n, :]['length_of_feature']
        if len_feature > 2:
            job_id =int( df.iloc[n, :]['job_id'])
            query_name = df.iloc[n, :]['feature'][0]
            signal = df.iloc[n, :]['feature'][1:-1]
            
            
            data = {'job_id': [job_id] * len(signal),
                    'query_name': [query_name] * len(signal),
                    'signal': signal}

            data_processed.append(pd.DataFrame(data))

    df = pd.concat(data_processed, axis=0)
    df['query_name'] = df['query_name'].str.split('|')
    df['signal'] = df['signal'].str.split('|')
    # get the length of signal name column
    df['length_of_query'] = [len(l) for l in df['query_name'].tolist()]
    df['length_of_signal'] = [len(l) for l in df['signal'].tolist()]
    
    


    signal_names = df['query_name'].iloc[0][0:-1]
        # for the 13 signals
    for i, signal_name in enumerate(signal_names):
        df[signal_name] = df['signal'].apply(lambda x:x[i])
        
        
        
    df['formatted_node_names'] = df['NodeList'].apply(format_node_names)
    df.drop(['query_name','signal', 'length_of_query',
                 'length_of_signal', 'JobName'], axis=1, inplace=True)

    df.rename(columns={"JobID":"Slurm_job_id"}, inplace=True)

 
    df.sort_values(by='job_id', inplace=True)


    return df

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
job_folder_path =  Path('/projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data')
job_file_paths = list(Path.glob(job_folder_path, "*.json"))
file_path_writing = job_folder_path / 'benchmark_job_data_cleaned.csv'

display(job_file_paths)
# Out:
# [PosixPath('/projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-12-11-09-32.json'),
#  PosixPath('/projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-12-11-10-06.json'),
#  PosixPath('/projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-11-20-12-42.json'),
#  PosixPath('/projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-11-20-14-47.json'),
#  PosixPath('/projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-11-20-13-45.json'),
#  PosixPath('/projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-11-20-11-54.json'),
#  PosixPath('/projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-11-20-14-28.json'),
#  PosixPath('/projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-12-11-09-49.json'),
#  PosixPath('/projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-12-11-09-13.json'),
#  PosixPath('/projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-11-20-14-10.json'),
#  PosixPath('/projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-12-11-10-39.json')]

# %%
main_key_list = ['jobid', 'name', 'system', 'result', 'nodelist', 'fail_reason', 
            'fail_phase', 'environment', 'time_compile', 'time_performance', 'time_run', 
            'time_sanity', 'time_setup', 'time_total']

pref_vars_key_list = ["name", "reference", "thres_lower", "thres_upper","unit","value"]



check_vars_key_list = ['valid_prog_environs', 'valid_systems', 'executable', 'executable_opts', 
                  'num_tasks', 'num_tasks_per_node', 'num_cpus_per_task', 'time_limit', 'prerun_cmds',
                  'postrun_cmds','modules', 'env_vars','readonly_files'
                  ]


df_list = []
for file_path in job_file_paths:
    print(file_path)
    all_job_data = extract_job_data(file_path, main_key_list, pref_vars_key_list, check_vars_key_list)
    # print([len(job) for job in all_job_data])
    # _ = pd.DataFrame(all_job_data)
    # if _.empty or _.isna().all().all():
    #     display(_.sample(n=10))
    df_list.append(pd.DataFrame(all_job_data))
    
df = pd.concat(df_list, axis=0, ignore_index=True)
# display(df.sample(n=10))


display(df.sample(n=10))
# Out:
# /projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-12-11-09-32.json
# /projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-12-11-10-06.json
# /projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-11-20-12-42.json
# /projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-11-20-14-47.json
# /projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-11-20-13-45.json
# /projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-11-20-11-54.json
# /projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-11-20-14-28.json
# /projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-12-11-09-49.json
# /projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-12-11-09-13.json
# /projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-11-20-14-10.json
# /projects/2/prjs1098/system_analytics_2024/prom_data/benchmark_single_node_job_data/AI_student_runs_single_2024-12-11-10-39.json
#        jobid                                              name  \
# 350     None  HemePure_CPUBuildTest ~snellius:gpu_h100+eb-foss
# 165  8618142                Palabos_CPU_WS %nnodes=1 %ppn=full
# 250  8618958                            HPCG_MPIOnly %nnodes=1
# 207  8616988                               VASP %version=6.4.2
# 347     None     HemePure_CPUBuildTest ~snellius:genoa+eb-foss
# 307     None                Palabos_CPU_WS %nnodes=1 %ppn=full
# 358  8618820         HemePure_CPU_SS_small %nnodes=1 %ppn=half
# 262     None        Palabos_CPUBuildTest ~snellius:fat+eb-foss
# 379  8995983                Palabos_CPU_WS %nnodes=1 %ppn=full
# 283     None         HemePure_CPU_SS_small %nnodes=1 %ppn=half
#
#                 system   result  nodelist  \
# 350  snellius:gpu_h100  success        []
# 165     snellius:genoa  success  [tcn650]
# 250     snellius:genoa  success  [tcn755]
# 207      snellius:rome  aborted        []
# 347     snellius:genoa  success        []
# 307  snellius:gpu_h100  failure        []
# 358       snellius:fat  success   [fcn40]
# 262       snellius:fat  success        []
# 379      snellius:rome  success  [tcn330]
# 283  snellius:gpu_a100  failure        []
#
#                                            fail_reason fail_phase  \
# 350                                               None       None
# 165                                               None       None
# 250                                               None       None
# 207                   aborted due to KeyboardInterrupt        run
# 347                                               None       None
# 307  spawned process error: command 'sbatch rfm_job...        run
# 358                                               None       None
# 262                                               None       None
# 379                                               None       None
# 283  spawned process error: command 'sbatch rfm_job...        run
#
#       environment  time_compile  time_performance     time_run  time_sanity  \
# 350       eb-foss    740.142676          0.007025     0.267144     0.007058
# 165       eb-foss      0.085410          0.065114   548.816145     0.033488
# 250  eb-intel-mpi     53.794621          0.036240   265.069486     0.125959
# 207       eb-foss      0.028758               NaN  1065.922933          NaN
# 347       eb-foss    808.143786          0.054098   138.546298     0.051725
# 307       eb-foss      0.117863               NaN     6.261048          NaN
# 358       eb-foss      0.201681          0.029072    98.782633     0.090209
# 262       eb-foss    140.493884          0.030935   527.950191     0.034180
# 379       eb-foss      0.093990          0.029506  1629.064777     0.113190
# 283       eb-foss      0.028610               NaN     1.744501          NaN
#
#      time_setup   time_total pref_name pref_reference pref_thres_lower  \
# 350    0.024316   917.256948   no_data        no_data          no_data
# 165    0.735287   554.503631     MLUPS              0             None
# 250    0.051595   555.047575    gflops              0             None
# 207    0.046753  1091.496335   no_data        no_data          no_data
# 347    0.022796   976.831596   no_data        no_data          no_data
# 307    0.146674    17.310231   no_data        no_data          no_data
# 358    0.222703   105.018171  NumSites              0             None
# 262    0.023578   690.318531   no_data        no_data          no_data
# 379    0.070935  1636.837000     MLUPS              0             None
# 283    0.046593     3.718218   no_data        no_data          no_data
#
#     pref_thres_upper pref_unit pref_value          valid_prog_environs  \
# 350          no_data   no_data    no_data                    [eb-foss]
# 165             None     MLUPS    215.439                    [eb-foss]
# 250             None   Gflop/s    66.2172  [eb-foss-mpi, eb-intel-mpi]
# 207          no_data   no_data    no_data                    [eb-foss]
# 347          no_data   no_data    no_data                    [eb-foss]
# 307          no_data   no_data    no_data                    [eb-foss]
# 358             None         s    18450.0                    [eb-foss]
# 262          no_data   no_data    no_data                    [eb-foss]
# 379             None     MLUPS    37.7511                    [eb-foss]
# 283          no_data   no_data    no_data                    [eb-foss]
#
#                                          valid_systems  \
# 350                                [snellius:gpu_h100]
# 165  [snellius:rome, snellius:fat, snellius:gpu_a10...
# 250  [lisa:silver, lisa:gold, snellius:rome, snelli...
# 207                    [snellius:rome, snellius:genoa]
# 347                                   [snellius:genoa]
# 307  [snellius:rome, snellius:fat, snellius:gpu_a10...
# 358  [snellius:rome, snellius:fat, snellius:gpu_a10...
# 262                                     [snellius:fat]
# 379  [snellius:rome, snellius:fat, snellius:gpu_a10...
# 283  [snellius:rome, snellius:fat, snellius:gpu_a10...
#
#                                             executable  \
# 350                   ./HemePure_CPUBuildTest_fad8439d
# 165  /scratch-shared/benjamic/reframe_output/stagin...
# 250                                     hpcg/bin/xhpcg
# 207                                           vasp_std
# 347                   ./HemePure_CPUBuildTest_2a752034
# 307  /scratch-shared/benjamic/reframe_output/stagin...
# 358  /scratch-shared/benjamic/reframe_output/stagin...
# 262                    ./Palabos_CPUBuildTest_00f7d1bf
# 379  /scratch-shared/benjamic/reframe_output/stagin...
# 283  /scratch-shared/benjamic/reframe_output/stagin...
#
#                                        executable_opts  num_tasks  \
# 350                                                 []          1
# 165  [/scratch-shared/benjamic/reframe_output/stagi...        192
# 250                [--nx=104, --ny=104, --nz=104, -t2]        192
# 207                                                 []        256
# 347                                                 []          1
# 307  [/scratch-shared/benjamic/reframe_output/stagi...         64
# 358  [ -in  /gpfs/work4/1/reframe0/resourcesdir/Hem...         64
# 262                                                 []          1
# 379  [/scratch-shared/benjamic/reframe_output/stagi...        128
# 283  [ -in  /gpfs/work4/1/reframe0/resourcesdir/Hem...         36
#
#      num_tasks_per_node  num_cpus_per_task  time_limit  \
# 350                 NaN                NaN      1800.0
# 165               192.0                NaN      1800.0
# 250               192.0                1.0      3600.0
# 207                 NaN                NaN     86400.0
# 347                 NaN                NaN      1800.0
# 307                64.0                NaN      1800.0
# 358                64.0                NaN      3540.0
# 262                 NaN                NaN         NaN
# 379               128.0                NaN      1800.0
# 283                36.0                NaN      3540.0
#
#                                            prerun_cmds  \
# 350                                                 []
# 165  [sed -i 's/<referenceResolution> 400 </<refere...
# 250                                                 []
# 207                                                 []
# 347                                                 []
# 307  [sed -i 's/<referenceResolution> 400 </<refere...
# 358                                                 []
# 262                                                 []
# 379  [sed -i 's/<referenceResolution> 400 </<refere...
# 283                                                 []
#
#                                           postrun_cmds  \
# 350                                                 []
# 165                                                 []
# 250                                                 []
# 207                                                 []
# 347                                                 []
# 307                                                 []
# 358  [cp results/report.txt /gpfs/home3/benjamic/Re...
# 262                                                 []
# 379                                                 []
# 283  [cp results/report.txt /gpfs/home3/benjamic/Re...
#
#                             modules env_vars readonly_files
# 350  [Python-bare-2.7.18, libtirpc]       {}             []
# 165                              []       {}             []
# 250                              []       {}             []
# 207               [vasp-foss-6.4.2]       {}             []
# 347  [Python-bare-2.7.18, libtirpc]       {}             []
# 307                              []       {}             []
# 358                              []       {}             []
# 262                              []       {}             []
# 379                              []       {}             []
# 283                              []       {}             []

# %%
mask = (df['jobid']=='None') | (df['jobid'].isna())

df_benckmark= df[~(mask)].copy()
df_benckmark['jobid'] = pd.to_numeric(df_benckmark['jobid']).astype('Int64')

print(f"How many potential jobs: {len(df)} and How many jobids are available: {len(df[~(mask)])}")
# Out:
# How many potential jobs: 405 and How many jobids are available: 235

# %%
""" 
Get the start time, end time and nodelist from slurm for the selected jobs
and merge them with the benchmark data
"""
df_slurm = get_slurm_data(df_benckmark['jobid'])
df_slurm_preprocessed = preprocess_slurm(df_slurm)

df = pd.merge(left=df_slurm_preprocessed, right=df_benckmark, how='inner',
              left_on='job_id', right_on='jobid')
display(df_slurm_preprocessed.head(n=5), df.head())
# Out:
#     job_id               Submit             Eligible                Start  \
# 0  8616980  2024-11-20T11:54:35  2024-11-20T11:54:35  2024-11-20T11:54:52
# 0  8616982  2024-11-20T11:54:38  2024-11-20T11:54:38  2024-11-20T11:54:41
# 0  8616984  2024-11-20T11:54:40  2024-11-20T11:54:40  2024-11-20T11:54:52
# 0  8616986  2024-11-20T11:54:43  2024-11-20T11:54:43  2024-11-20T11:54:52
# 0  8616988  2024-11-20T11:55:00  2024-11-20T11:55:00  2024-11-20T11:55:22
#
#                    End   Elapsed Slurm_job_id               State AllocCPUS  \
# 0  2024-11-20T12:07:43  00:12:51      8616980           COMPLETED        72
# 0  2024-11-20T12:07:18  00:12:37      8616982           COMPLETED        64
# 0  2024-11-20T12:08:01  00:13:09      8616984           COMPLETED       128
# 0  2024-11-20T12:07:56  00:13:04      8616986           COMPLETED       192
# 0  2024-11-20T12:12:54  00:17:32      8616988  CANCELLED by 54971       256
#
#    TotalCPU      NodeList formatted_node_names
# 0  00:00:00         gcn49                gcn49
# 0  00:00:00        gcn149               gcn149
# 0  00:00:00        tcn109               tcn109
# 0  00:00:00        tcn575               tcn575
# 0  00:00:00  tcn[149,151]        tcn149,tcn151
#     job_id               Submit             Eligible                Start  \
# 0  8616980  2024-11-20T11:54:35  2024-11-20T11:54:35  2024-11-20T11:54:52
# 1  8616982  2024-11-20T11:54:38  2024-11-20T11:54:38  2024-11-20T11:54:41
# 2  8616984  2024-11-20T11:54:40  2024-11-20T11:54:40  2024-11-20T11:54:52
# 3  8616986  2024-11-20T11:54:43  2024-11-20T11:54:43  2024-11-20T11:54:52
# 4  8616988  2024-11-20T11:55:00  2024-11-20T11:55:00  2024-11-20T11:55:22
#
#                    End   Elapsed Slurm_job_id               State AllocCPUS  \
# 0  2024-11-20T12:07:43  00:12:51      8616980           COMPLETED        72
# 1  2024-11-20T12:07:18  00:12:37      8616982           COMPLETED        64
# 2  2024-11-20T12:08:01  00:13:09      8616984           COMPLETED       128
# 3  2024-11-20T12:07:56  00:13:04      8616986           COMPLETED       192
# 4  2024-11-20T12:12:54  00:17:32      8616988  CANCELLED by 54971       256
#
#    TotalCPU      NodeList formatted_node_names    jobid  \
# 0  00:00:00         gcn49                gcn49  8616980
# 1  00:00:00        gcn149               gcn149  8616982
# 2  00:00:00        tcn109               tcn109  8616984
# 3  00:00:00        tcn575               tcn575  8616986
# 4  00:00:00  tcn[149,151]        tcn149,tcn151  8616988
#
#                       name             system   result  nodelist  \
# 0    GROMACS_GPU %n_gpus=1  snellius:gpu_a100  success   [gcn49]
# 1    GROMACS_GPU %n_gpus=1  snellius:gpu_h100  success  [gcn149]
# 2  GROMACS_CPU %n_cores=32      snellius:rome  success  [tcn109]
# 3  GROMACS_CPU %n_cores=32     snellius:genoa  success  [tcn575]
# 4      VASP %version=6.4.2      snellius:rome  aborted        []
#
#                         fail_reason fail_phase  environment  time_compile  \
# 0                              None       None      eb-foss      0.029076
# 1                              None       None      eb-foss      0.028724
# 2                              None       None  eb-foss-mpi      0.028928
# 3                              None       None  eb-foss-mpi      0.029197
# 4  aborted due to KeyboardInterrupt        run      eb-foss      0.028758
#
#    time_performance     time_run  time_sanity  time_setup   time_total  \
# 0          0.227419   792.553260     0.096275    0.527797   794.377215
# 1          0.073034   766.922158     0.097536    0.048740   770.778406
# 2          0.179587   806.839507     0.187784    0.047647   813.222719
# 3          0.046268   798.165663     0.052712    0.047641   806.888496
# 4               NaN  1065.922933          NaN    0.046753  1091.496335
#
#   pref_name pref_reference pref_thres_lower pref_thres_upper pref_unit  \
# 0      perf              0             None             None    ns/day
# 1      perf              0             None             None    ns/day
# 2      perf              0             None             None    ns/day
# 3      perf              0             None             None    ns/day
# 4   no_data        no_data          no_data          no_data   no_data
#
#   pref_value valid_prog_environs                           valid_systems  \
# 0     16.529           [eb-foss]  [snellius:gpu_a100, snellius:gpu_h100]
# 1     25.705           [eb-foss]  [snellius:gpu_a100, snellius:gpu_h100]
# 2      3.262       [eb-foss-mpi]         [snellius:rome, snellius:genoa]
# 3      3.343       [eb-foss-mpi]         [snellius:rome, snellius:genoa]
# 4    no_data           [eb-foss]         [snellius:rome, snellius:genoa]
#
#   executable                                    executable_opts  num_tasks  \
# 0    gmx_mpi  [mdrun -v -pin on -dlb yes -resethway -deffnm ...          1
# 1    gmx_mpi  [mdrun -v -pin on -dlb yes -resethway -deffnm ...          1
# 2    gmx_mpi  [mdrun -v -pin on -dlb yes -resethway -deffnm ...         32
# 3    gmx_mpi  [mdrun -v -pin on -dlb yes -resethway -deffnm ...         32
# 4   vasp_std                                                 []        256
#
#    num_tasks_per_node  num_cpus_per_task  time_limit  \
# 0                 1.0               18.0      1800.0
# 1                 1.0               16.0      1800.0
# 2                32.0                1.0      1800.0
# 3                32.0                1.0      1800.0
# 4                 NaN                NaN     86400.0
#
#                                          prerun_cmds postrun_cmds  \
# 0  [cp /gpfs/work4/1/reframe0/resourcesdir/gromac...           []
# 1  [cp /gpfs/work4/1/reframe0/resourcesdir/gromac...           []
# 2  [cp /gpfs/work4/1/reframe0/resourcesdir/gromac...           []
# 3  [cp /gpfs/work4/1/reframe0/resourcesdir/gromac...           []
# 4                                                 []           []
#
#               modules env_vars readonly_files
# 0  [gromacs-foss-gpu]       {}             []
# 1  [gromacs-foss-gpu]       {}             []
# 2      [gromacs-foss]       {}             []
# 3      [gromacs-foss]       {}             []
# 4   [vasp-foss-6.4.2]       {}             []

# %%
""" 
For some jobs the start time is None! 
they have job ids, but no record comes out
"""
mask = (df['Start']=='None') 
display(df[mask])
df = df[~mask].copy()
# Out:
# Empty DataFrame
# Columns: [job_id, Submit, Eligible, Start, End, Elapsed, Slurm_job_id, State, AllocCPUS, TotalCPU, NodeList, formatted_node_names, jobid, name, system, result, nodelist, fail_reason, fail_phase, environment, time_compile, time_performance, time_run, time_sanity, time_setup, time_total, pref_name, pref_reference, pref_thres_lower, pref_thres_upper, pref_unit, pref_value, valid_prog_environs, valid_systems, executable, executable_opts, num_tasks, num_tasks_per_node, num_cpus_per_task, time_limit, prerun_cmds, postrun_cmds, modules, env_vars, readonly_files]
# Index: []

# %%
# removing all the step ids
df = df[(df['Slurm_job_id'].str.contains(pat='^\\d+$', regex=True))]
df.head()
# Out:
#     job_id               Submit             Eligible                Start  \
# 0  8616980  2024-11-20T11:54:35  2024-11-20T11:54:35  2024-11-20T11:54:52
# 1  8616982  2024-11-20T11:54:38  2024-11-20T11:54:38  2024-11-20T11:54:41
# 2  8616984  2024-11-20T11:54:40  2024-11-20T11:54:40  2024-11-20T11:54:52
# 3  8616986  2024-11-20T11:54:43  2024-11-20T11:54:43  2024-11-20T11:54:52
# 4  8616988  2024-11-20T11:55:00  2024-11-20T11:55:00  2024-11-20T11:55:22
#
#                    End   Elapsed Slurm_job_id               State AllocCPUS  \
# 0  2024-11-20T12:07:43  00:12:51      8616980           COMPLETED        72
# 1  2024-11-20T12:07:18  00:12:37      8616982           COMPLETED        64
# 2  2024-11-20T12:08:01  00:13:09      8616984           COMPLETED       128
# 3  2024-11-20T12:07:56  00:13:04      8616986           COMPLETED       192
# 4  2024-11-20T12:12:54  00:17:32      8616988  CANCELLED by 54971       256
#
#    TotalCPU      NodeList formatted_node_names    jobid  \
# 0  00:00:00         gcn49                gcn49  8616980
# 1  00:00:00        gcn149               gcn149  8616982
# 2  00:00:00        tcn109               tcn109  8616984
# 3  00:00:00        tcn575               tcn575  8616986
# 4  00:00:00  tcn[149,151]        tcn149,tcn151  8616988
#
#                       name             system   result  nodelist  \
# 0    GROMACS_GPU %n_gpus=1  snellius:gpu_a100  success   [gcn49]
# 1    GROMACS_GPU %n_gpus=1  snellius:gpu_h100  success  [gcn149]
# 2  GROMACS_CPU %n_cores=32      snellius:rome  success  [tcn109]
# 3  GROMACS_CPU %n_cores=32     snellius:genoa  success  [tcn575]
# 4      VASP %version=6.4.2      snellius:rome  aborted        []
#
#                         fail_reason fail_phase  environment  time_compile  \
# 0                              None       None      eb-foss      0.029076
# 1                              None       None      eb-foss      0.028724
# 2                              None       None  eb-foss-mpi      0.028928
# 3                              None       None  eb-foss-mpi      0.029197
# 4  aborted due to KeyboardInterrupt        run      eb-foss      0.028758
#
#    time_performance     time_run  time_sanity  time_setup   time_total  \
# 0          0.227419   792.553260     0.096275    0.527797   794.377215
# 1          0.073034   766.922158     0.097536    0.048740   770.778406
# 2          0.179587   806.839507     0.187784    0.047647   813.222719
# 3          0.046268   798.165663     0.052712    0.047641   806.888496
# 4               NaN  1065.922933          NaN    0.046753  1091.496335
#
#   pref_name pref_reference pref_thres_lower pref_thres_upper pref_unit  \
# 0      perf              0             None             None    ns/day
# 1      perf              0             None             None    ns/day
# 2      perf              0             None             None    ns/day
# 3      perf              0             None             None    ns/day
# 4   no_data        no_data          no_data          no_data   no_data
#
#   pref_value valid_prog_environs                           valid_systems  \
# 0     16.529           [eb-foss]  [snellius:gpu_a100, snellius:gpu_h100]
# 1     25.705           [eb-foss]  [snellius:gpu_a100, snellius:gpu_h100]
# 2      3.262       [eb-foss-mpi]         [snellius:rome, snellius:genoa]
# 3      3.343       [eb-foss-mpi]         [snellius:rome, snellius:genoa]
# 4    no_data           [eb-foss]         [snellius:rome, snellius:genoa]
#
#   executable                                    executable_opts  num_tasks  \
# 0    gmx_mpi  [mdrun -v -pin on -dlb yes -resethway -deffnm ...          1
# 1    gmx_mpi  [mdrun -v -pin on -dlb yes -resethway -deffnm ...          1
# 2    gmx_mpi  [mdrun -v -pin on -dlb yes -resethway -deffnm ...         32
# 3    gmx_mpi  [mdrun -v -pin on -dlb yes -resethway -deffnm ...         32
# 4   vasp_std                                                 []        256
#
#    num_tasks_per_node  num_cpus_per_task  time_limit  \
# 0                 1.0               18.0      1800.0
# 1                 1.0               16.0      1800.0
# 2                32.0                1.0      1800.0
# 3                32.0                1.0      1800.0
# 4                 NaN                NaN     86400.0
#
#                                          prerun_cmds postrun_cmds  \
# 0  [cp /gpfs/work4/1/reframe0/resourcesdir/gromac...           []
# 1  [cp /gpfs/work4/1/reframe0/resourcesdir/gromac...           []
# 2  [cp /gpfs/work4/1/reframe0/resourcesdir/gromac...           []
# 3  [cp /gpfs/work4/1/reframe0/resourcesdir/gromac...           []
# 4                                                 []           []
#
#               modules env_vars readonly_files
# 0  [gromacs-foss-gpu]       {}             []
# 1  [gromacs-foss-gpu]       {}             []
# 2      [gromacs-foss]       {}             []
# 3      [gromacs-foss]       {}             []
# 4   [vasp-foss-6.4.2]       {}             []

# %%
# remove all the rows that are not completed
mask = ~(df['State']=='COMPLETED')
display(df[mask])
df = df[~mask].copy()
# Out:
#       job_id               Submit             Eligible                Start  \
# 4    8616988  2024-11-20T11:55:00  2024-11-20T11:55:00  2024-11-20T11:55:22
# 5    8616990  2024-11-20T11:55:03  2024-11-20T11:55:03  2024-11-20T11:55:06
# 6    8617010  2024-11-20T11:57:03  2024-11-20T11:57:03  2024-11-20T11:57:22
# 12   8617019  2024-11-20T11:57:36  2024-11-20T11:57:36  2024-11-20T11:57:38
# 14   8617022  2024-11-20T11:57:42  2024-11-20T11:57:42  2024-11-20T11:57:43
# 25   8617372  2024-11-20T12:47:44  2024-11-20T12:47:44  2024-11-20T12:47:56
# 28   8617376  2024-11-20T12:48:32  2024-11-20T12:48:32  2024-11-20T12:48:39
# 29   8617377  2024-11-20T12:48:58  2024-11-20T12:48:58  2024-11-20T12:49:00
# 113  8619477  2024-11-20T14:51:58  2024-11-20T14:51:58  2024-11-20T14:52:09
# 116  8619502  2024-11-20T14:52:55  2024-11-20T14:52:55  2024-11-20T14:52:56
# 118  8619515  2024-11-20T14:53:33  2024-11-20T14:53:33  2024-11-20T14:53:36
# 417  8995620  2024-12-11T10:08:43  2024-12-11T10:08:43  2024-12-11T10:08:50
# 520  8995993  2024-12-11T10:43:20  2024-12-11T10:43:20  2024-12-11T10:43:23
# 529  8996005  2024-12-11T10:44:12  2024-12-11T10:44:12  2024-12-11T10:44:20
# 540  8996008  2024-12-11T10:44:43  2024-12-11T10:44:43  2024-12-11T10:44:53
#
#                      End   Elapsed Slurm_job_id               State AllocCPUS  \
# 4    2024-11-20T12:12:54  00:17:32      8616988  CANCELLED by 54971       256
# 5    2024-11-20T12:12:54  00:17:48      8616990  CANCELLED by 54971       384
# 6    2024-11-20T11:57:40  00:00:18      8617010              FAILED       128
# 12   2024-11-20T11:58:26  00:00:48      8617019              FAILED       192
# 14   2024-11-20T11:58:20  00:00:37      8617022              FAILED       128
# 25   2024-11-20T12:48:13  00:00:17      8617372              FAILED       128
# 28   2024-11-20T12:49:27  00:00:48      8617376              FAILED       192
# 29   2024-11-20T12:49:18  00:00:18      8617377              FAILED       128
# 113  2024-11-20T14:52:29  00:00:20      8619477              FAILED       128
# 116  2024-11-20T14:53:27  00:00:31      8619502              FAILED       192
# 118  2024-11-20T14:53:56  00:00:20      8619515              FAILED       128
# 417  2024-12-11T10:38:56  00:30:06      8995620             TIMEOUT       128
# 520  2024-12-11T10:43:41  00:00:18      8995993              FAILED       128
# 529  2024-12-11T10:44:49  00:00:29      8996005              FAILED       192
# 540  2024-12-11T10:45:12  00:00:19      8996008              FAILED       128
#
#        TotalCPU      NodeList formatted_node_names    jobid  \
# 4      00:00:00  tcn[149,151]        tcn149,tcn151  8616988
# 5      00:00:00  tcn[888,893]        tcn888,tcn893  8616990
# 6      00:00:00        tcn306               tcn306  8617010
# 12     00:00:00       tcn1005              tcn1005  8617019
# 14     00:00:00         fcn62                fcn62  8617022
# 25     00:00:00        tcn306               tcn306  8617372
# 28     00:00:00       tcn1014              tcn1014  8617376
# 29     00:00:00         fcn40                fcn40  8617377
# 113    00:00:00        tcn431               tcn431  8619477
# 116    00:00:00        tcn586               tcn586  8619502
# 118    00:00:00         fcn62                fcn62  8619515
# 417  2-13:28:37         tcn22                tcn22  8995620
# 520   00:28.858        tcn349               tcn349  8995993
# 529   01:03.494        tcn745               tcn745  8996005
# 540   00:24.108         fcn59                fcn59  8996008
#
#                                    name          system   result   nodelist  \
# 4                   VASP %version=6.4.2   snellius:rome  aborted         []
# 5                   VASP %version=6.4.2  snellius:genoa  aborted         []
# 6                HPCG_MPIOnly %nnodes=1   snellius:rome  failure   [tcn306]
# 12               HPCG_MPIOnly %nnodes=1  snellius:genoa  failure  [tcn1005]
# 14               HPCG_MPIOnly %nnodes=1    snellius:fat  failure    [fcn62]
# 25               HPCG_MPIOnly %nnodes=1   snellius:rome  failure   [tcn306]
# 28               HPCG_MPIOnly %nnodes=1  snellius:genoa  failure  [tcn1014]
# 29               HPCG_MPIOnly %nnodes=1    snellius:fat  failure    [fcn40]
# 113              HPCG_MPIOnly %nnodes=1   snellius:rome  failure   [tcn431]
# 116              HPCG_MPIOnly %nnodes=1  snellius:genoa  failure   [tcn586]
# 118              HPCG_MPIOnly %nnodes=1    snellius:fat  failure    [fcn62]
# 417  Palabos_CPU_WS %nnodes=1 %ppn=full   snellius:rome  success    [tcn22]
# 520              HPCG_MPIOnly %nnodes=1   snellius:rome  failure   [tcn349]
# 529              HPCG_MPIOnly %nnodes=1  snellius:genoa  failure   [tcn745]
# 540              HPCG_MPIOnly %nnodes=1    snellius:fat  failure    [fcn59]
#
#                               fail_reason fail_phase   environment  \
# 4        aborted due to KeyboardInterrupt        run       eb-foss
# 5        aborted due to KeyboardInterrupt        run       eb-foss
# 6    sanity error: index out of bounds: 0     sanity  eb-intel-mpi
# 12   sanity error: index out of bounds: 0     sanity  eb-intel-mpi
# 14   sanity error: index out of bounds: 0     sanity  eb-intel-mpi
# 25   sanity error: index out of bounds: 0     sanity  eb-intel-mpi
# 28   sanity error: index out of bounds: 0     sanity  eb-intel-mpi
# 29   sanity error: index out of bounds: 0     sanity  eb-intel-mpi
# 113  sanity error: index out of bounds: 0     sanity  eb-intel-mpi
# 116  sanity error: index out of bounds: 0     sanity  eb-intel-mpi
# 118  sanity error: index out of bounds: 0     sanity  eb-intel-mpi
# 417                                  None       None       eb-foss
# 520  sanity error: index out of bounds: 0     sanity  eb-intel-mpi
# 529  sanity error: index out of bounds: 0     sanity  eb-intel-mpi
# 540  sanity error: index out of bounds: 0     sanity  eb-intel-mpi
#
#      time_compile  time_performance     time_run  time_sanity  time_setup  \
# 4        0.028758               NaN  1065.922933          NaN    0.046753
# 5        0.028725               NaN  1063.542924          NaN    0.047807
# 6      115.829539               NaN    40.982624     0.250703    0.052086
# 12      32.440213               NaN    52.282237     0.033061    0.051539
# 14      32.372833               NaN    41.648577     0.031247    0.051604
# 25      57.932809               NaN    35.176644     0.100945    0.223092
# 28      52.118239               NaN    58.920915     0.086645    0.051461
# 29      49.913301               NaN    25.175953     0.124615    0.050967
# 113     63.662785               NaN    37.014676     0.062711    0.057766
# 116     60.390557               NaN    37.524774     0.059154    0.058495
# 118     52.479463               NaN    27.834000     0.049162    0.063187
# 417      0.921382          0.042945  1824.563833     0.032942    0.884215
# 520     60.652275               NaN    26.371520     0.055132    0.052857
# 529     56.015639               NaN    41.589759     0.050814    0.052891
# 540     51.853648               NaN    34.636387     0.046731    0.053236
#
#       time_total pref_name pref_reference pref_thres_lower pref_thres_upper  \
# 4    1091.496335   no_data        no_data          no_data          no_data
# 5    1091.422901   no_data        no_data          no_data          no_data
# 6     190.089140   no_data        no_data          no_data          no_data
# 12    234.739804   no_data        no_data          no_data          no_data
# 14    229.765781   no_data        no_data          no_data          no_data
# 25    308.427281   no_data        no_data          no_data          no_data
# 28    381.053181   no_data        no_data          no_data          no_data
# 29    372.578818   no_data        no_data          no_data          no_data
# 113   281.118705   no_data        no_data          no_data          no_data
# 116   338.917252   no_data        no_data          no_data          no_data
# 118   366.705195   no_data        no_data          no_data          no_data
# 417  1829.624403   no_data        no_data          no_data          no_data
# 520   256.683187   no_data        no_data          no_data          no_data
# 529   324.479944   no_data        no_data          no_data          no_data
# 540   348.379438   no_data        no_data          no_data          no_data
#
#     pref_unit pref_value          valid_prog_environs  \
# 4     no_data    no_data                    [eb-foss]
# 5     no_data    no_data                    [eb-foss]
# 6     no_data    no_data  [eb-foss-mpi, eb-intel-mpi]
# 12    no_data    no_data  [eb-foss-mpi, eb-intel-mpi]
# 14    no_data    no_data  [eb-foss-mpi, eb-intel-mpi]
# 25    no_data    no_data  [eb-foss-mpi, eb-intel-mpi]
# 28    no_data    no_data  [eb-foss-mpi, eb-intel-mpi]
# 29    no_data    no_data  [eb-foss-mpi, eb-intel-mpi]
# 113   no_data    no_data  [eb-foss-mpi, eb-intel-mpi]
# 116   no_data    no_data  [eb-foss-mpi, eb-intel-mpi]
# 118   no_data    no_data  [eb-foss-mpi, eb-intel-mpi]
# 417   no_data    no_data                    [eb-foss]
# 520   no_data    no_data  [eb-foss-mpi, eb-intel-mpi]
# 529   no_data    no_data  [eb-foss-mpi, eb-intel-mpi]
# 540   no_data    no_data  [eb-foss-mpi, eb-intel-mpi]
#
#                                          valid_systems  \
# 4                      [snellius:rome, snellius:genoa]
# 5                      [snellius:rome, snellius:genoa]
# 6    [lisa:silver, lisa:gold, snellius:rome, snelli...
# 12   [lisa:silver, lisa:gold, snellius:rome, snelli...
# 14   [lisa:silver, lisa:gold, snellius:rome, snelli...
# 25   [lisa:silver, lisa:gold, snellius:rome, snelli...
# 28   [lisa:silver, lisa:gold, snellius:rome, snelli...
# 29   [lisa:silver, lisa:gold, snellius:rome, snelli...
# 113  [lisa:silver, lisa:gold, snellius:rome, snelli...
# 116  [lisa:silver, lisa:gold, snellius:rome, snelli...
# 118  [lisa:silver, lisa:gold, snellius:rome, snelli...
# 417  [snellius:rome, snellius:fat, snellius:gpu_a10...
# 520  [lisa:silver, lisa:gold, snellius:rome, snelli...
# 529  [lisa:silver, lisa:gold, snellius:rome, snelli...
# 540  [lisa:silver, lisa:gold, snellius:rome, snelli...
#
#                                             executable  \
# 4                                             vasp_std
# 5                                             vasp_std
# 6                                       hpcg/bin/xhpcg
# 12                                      hpcg/bin/xhpcg
# 14                                      hpcg/bin/xhpcg
# 25                                      hpcg/bin/xhpcg
# 28                                      hpcg/bin/xhpcg
# 29                                      hpcg/bin/xhpcg
# 113                                     hpcg/bin/xhpcg
# 116                                     hpcg/bin/xhpcg
# 118                                     hpcg/bin/xhpcg
# 417  /scratch-shared/benjamic/reframe_output/stagin...
# 520                                     hpcg/bin/xhpcg
# 529                                     hpcg/bin/xhpcg
# 540                                     hpcg/bin/xhpcg
#
#                                        executable_opts  num_tasks  \
# 4                                                   []        256
# 5                                                   []        384
# 6                  [--nx=104, --ny=104, --nz=104, -t2]        128
# 12                 [--nx=104, --ny=104, --nz=104, -t2]        192
# 14                 [--nx=104, --ny=104, --nz=104, -t2]        128
# 25                 [--nx=104, --ny=104, --nz=104, -t2]        128
# 28                 [--nx=104, --ny=104, --nz=104, -t2]        192
# 29                 [--nx=104, --ny=104, --nz=104, -t2]        128
# 113                [--nx=104, --ny=104, --nz=104, -t2]        128
# 116                [--nx=104, --ny=104, --nz=104, -t2]        192
# 118                [--nx=104, --ny=104, --nz=104, -t2]        128
# 417  [/scratch-shared/benjamic/reframe_output/stagi...        128
# 520                [--nx=104, --ny=104, --nz=104, -t2]        128
# 529                [--nx=104, --ny=104, --nz=104, -t2]        192
# 540                [--nx=104, --ny=104, --nz=104, -t2]        128
#
#      num_tasks_per_node  num_cpus_per_task  time_limit  \
# 4                   NaN                NaN     86400.0
# 5                   NaN                NaN     86400.0
# 6                 128.0                1.0      3600.0
# 12                192.0                1.0      3600.0
# 14                128.0                1.0      3600.0
# 25                128.0                1.0      3600.0
# 28                192.0                1.0      3600.0
# 29                128.0                1.0      3600.0
# 113               128.0                1.0      3600.0
# 116               192.0                1.0      3600.0
# 118               128.0                1.0      3600.0
# 417               128.0                NaN      1800.0
# 520               128.0                1.0      3600.0
# 529               192.0                1.0      3600.0
# 540               128.0                1.0      3600.0
#
#                                            prerun_cmds postrun_cmds  \
# 4                                                   []           []
# 5                                                   []           []
# 6                                                   []           []
# 12                                                  []           []
# 14                                                  []           []
# 25                                                  []           []
# 28                                                  []           []
# 29                                                  []           []
# 113                                                 []           []
# 116                                                 []           []
# 118                                                 []           []
# 417  [sed -i 's/<referenceResolution> 400 </<refere...           []
# 520                                                 []           []
# 529                                                 []           []
# 540                                                 []           []
#
#                modules env_vars readonly_files
# 4    [vasp-foss-6.4.2]       {}             []
# 5    [vasp-foss-6.4.2]       {}             []
# 6                   []       {}             []
# 12                  []       {}             []
# 14                  []       {}             []
# 25                  []       {}             []
# 28                  []       {}             []
# 29                  []       {}             []
# 113                 []       {}             []
# 116                 []       {}             []
# 118                 []       {}             []
# 417                 []       {}             []
# 520                 []       {}             []
# 529                 []       {}             []
# 540                 []       {}             []

# %%
# drop not useful columns
df.drop(['NodeList', 'jobid', 'nodelist'], inplace=True, axis=1)
df.rename(columns={"formatted_node_names":"node_list"}, inplace=True)
df.columns = df.columns.str.lower()
display(df.head())
print(len(df))
# Out:
#     job_id               submit             eligible                start  \
# 0  8616980  2024-11-20T11:54:35  2024-11-20T11:54:35  2024-11-20T11:54:52
# 1  8616982  2024-11-20T11:54:38  2024-11-20T11:54:38  2024-11-20T11:54:41
# 2  8616984  2024-11-20T11:54:40  2024-11-20T11:54:40  2024-11-20T11:54:52
# 3  8616986  2024-11-20T11:54:43  2024-11-20T11:54:43  2024-11-20T11:54:52
# 7  8617011  2024-11-20T11:57:08  2024-11-20T11:57:08  2024-11-20T11:57:22
#
#                    end   elapsed slurm_job_id      state alloccpus  totalcpu  \
# 0  2024-11-20T12:07:43  00:12:51      8616980  COMPLETED        72  00:00:00
# 1  2024-11-20T12:07:18  00:12:37      8616982  COMPLETED        64  00:00:00
# 2  2024-11-20T12:08:01  00:13:09      8616984  COMPLETED       128  00:00:00
# 3  2024-11-20T12:07:56  00:13:04      8616986  COMPLETED       192  00:00:00
# 7  2024-11-20T12:02:20  00:04:58      8617011  COMPLETED       128  00:00:00
#
#   node_list                     name             system   result fail_reason  \
# 0     gcn49    GROMACS_GPU %n_gpus=1  snellius:gpu_a100  success        None
# 1    gcn149    GROMACS_GPU %n_gpus=1  snellius:gpu_h100  success        None
# 2    tcn109  GROMACS_CPU %n_cores=32      snellius:rome  success        None
# 3    tcn575  GROMACS_CPU %n_cores=32     snellius:genoa  success        None
# 7    tcn111   HPCG_MPIOnly %nnodes=1      snellius:rome  success        None
#
#   fail_phase  environment  time_compile  time_performance    time_run  \
# 0       None      eb-foss      0.029076          0.227419  792.553260
# 1       None      eb-foss      0.028724          0.073034  766.922158
# 2       None  eb-foss-mpi      0.028928          0.179587  806.839507
# 3       None  eb-foss-mpi      0.029197          0.046268  798.165663
# 7       None  eb-foss-mpi    120.110956          0.027074  318.363357
#
#    time_sanity  time_setup  time_total pref_name pref_reference  \
# 0     0.096275    0.527797  794.377215      perf              0
# 1     0.097536    0.048740  770.778406      perf              0
# 2     0.187784    0.047647  813.222719      perf              0
# 3     0.052712    0.047641  806.888496      perf              0
# 7     0.167167    0.051292  472.052970    gflops              0
#
#   pref_thres_lower pref_thres_upper pref_unit pref_value  \
# 0             None             None    ns/day     16.529
# 1             None             None    ns/day     25.705
# 2             None             None    ns/day      3.262
# 3             None             None    ns/day      3.343
# 7             None             None   Gflop/s     37.848
#
#            valid_prog_environs  \
# 0                    [eb-foss]
# 1                    [eb-foss]
# 2                [eb-foss-mpi]
# 3                [eb-foss-mpi]
# 7  [eb-foss-mpi, eb-intel-mpi]
#
#                                        valid_systems      executable  \
# 0             [snellius:gpu_a100, snellius:gpu_h100]         gmx_mpi
# 1             [snellius:gpu_a100, snellius:gpu_h100]         gmx_mpi
# 2                    [snellius:rome, snellius:genoa]         gmx_mpi
# 3                    [snellius:rome, snellius:genoa]         gmx_mpi
# 7  [lisa:silver, lisa:gold, snellius:rome, snelli...  hpcg/bin/xhpcg
#
#                                      executable_opts  num_tasks  \
# 0  [mdrun -v -pin on -dlb yes -resethway -deffnm ...          1
# 1  [mdrun -v -pin on -dlb yes -resethway -deffnm ...          1
# 2  [mdrun -v -pin on -dlb yes -resethway -deffnm ...         32
# 3  [mdrun -v -pin on -dlb yes -resethway -deffnm ...         32
# 7                [--nx=104, --ny=104, --nz=104, -t2]        128
#
#    num_tasks_per_node  num_cpus_per_task  time_limit  \
# 0                 1.0               18.0      1800.0
# 1                 1.0               16.0      1800.0
# 2                32.0                1.0      1800.0
# 3                32.0                1.0      1800.0
# 7               128.0                1.0      3600.0
#
#                                          prerun_cmds postrun_cmds  \
# 0  [cp /gpfs/work4/1/reframe0/resourcesdir/gromac...           []
# 1  [cp /gpfs/work4/1/reframe0/resourcesdir/gromac...           []
# 2  [cp /gpfs/work4/1/reframe0/resourcesdir/gromac...           []
# 3  [cp /gpfs/work4/1/reframe0/resourcesdir/gromac...           []
# 7                                                 []           []
#
#               modules env_vars readonly_files
# 0  [gromacs-foss-gpu]       {}             []
# 1  [gromacs-foss-gpu]       {}             []
# 2      [gromacs-foss]       {}             []
# 3      [gromacs-foss]       {}             []
# 7                  []       {}             []
# 220

# %%
df['node_list'].value_counts()
# Out:
# node_list
# fcn40      24
# tcn738     10
# fcn25      10
# tcn575      9
# fcn45       8
# tcn607      6
# tcn745      5
# tcn306      5
# tcn109      5
# tcn281      5
# tcn262      5
# tcn354      5
# tcn22       5
# tcn561      5
# tcn589      4
# tcn552      4
# tcn111      4
# fcn62       4
# tcn356      4
# fcn49       4
# gcn22       4
# tcn747      4
# tcn146      3
# gcn49       3
# tcn408      3
# fcn52       3
# gcn108      3
# tcn291      3
# tcn755      3
# fcn41       3
# tcn114      2
# tcn750      2
# fcn60       2
# tcn597      2
# gcn131      2
# tcn558      2
# tcn77       2
# tcn650      2
# gcn69       2
# tcn417      2
# tcn6        2
# tcn593      2
# tcn808      2
# tcn349      2
# gcn149      1
# tcn584      1
# tcn135      1
# tcn329      1
# gcn111      1
# tcn1005     1
# tcn105      1
# gcn122      1
# tcn83       1
# tcn86       1
# tcn569      1
# fcn64       1
# tcn144      1
# tcn331      1
# gcn17       1
# tcn90       1
# tcn664      1
# tcn645      1
# tcn586      1
# tcn527      1
# tcn1014     1
# gcn128      1
# tcn334      1
# gcn119      1
# gcn134      1
# tcn178      1
# gcn46       1
# tcn104      1
# tcn330      1
# Name: count, dtype: int64

# %%
# df.to_csv(file_path_writing, index=False)
